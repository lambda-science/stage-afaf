# %%
import pandas as pd

# %%
df= pd.read_csv('muscle_atlas.csv')
df
# Out:
#       ordered    Number              File name      Organism     muscle  \
# 0           1     1.jpg   1 10199  aDG-25a.jpg  Homo sapiens    deltoid
# 1           2     2.jpg   2 10199  aDG-25b.jpg  Homo sapiens    deltoid
# 2           3     3.jpg    3 10199  bDG-25.jpg  Homo sapiens    deltoid
# 3           4     4.jpg     4 10199 COX-20.jpg  Homo sapiens    deltoid
# 4           5     5.jpg      5 10199 HE-20.jpg  Homo sapiens    deltoid
# ...       ...       ...                    ...           ...        ...
# 5465     5475  5475.jpg        9948 SDH-20.jpg  Homo sapiens    deltoid
# 5466     5476  5476.jpg         9948 TG-20.jpg  Homo sapiens    deltoid
# 5467     5477  5477.jpg  Temoin Emerine-10.jpg  Homo sapiens        NaN
# 5468     5478  5478.jpg  Temoin Emerine-20.jpg  Homo sapiens        NaN
# 5469     5479  5479.jpg                    NaN  Mus musculus  Whole leg
#
#              Disease Group                                   Diag.Final  \
# ...

# %%
df.dtypes
# Out:
# ordered                  int64
# Number                  object
# File name               object
# Organism                object
# muscle                  object
# Disease Group           object
# Diag.Final              object
# GENE                    object
# Staining method         object
# Age                     object
# Antibody reference      object
# Calibration (um/px)    float64
# Magnification           object
# Scale bar               object
# Treatment               object
# SEXE                    object
# OMIM                    object
# Mutated gene            object
# Excluded Genes          object
# Publication             object
# Link                    object
# dtype: object

# %%
NaN = df.isna().sum()

NaN
# Out:
# ordered                   0
# Number                    0
# File name                 1
# Organism                  0
# muscle                   11
# Disease Group           530
# Diag.Final              242
# GENE                     81
# Staining method           2
# Age                      43
# Antibody reference     5408
# Calibration (um/px)     144
# Magnification             8
# Scale bar               467
# Treatment                 0
# SEXE                    243
# OMIM                    643
# Mutated gene            125
# Excluded Genes         4489
# Publication            3182
# Link                   4780
# dtype: int64

# %%
#Pour notre calibration on voit que 144 image n'en ont pas, je vais supprimer les lignes

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5465    False
# 5466    False
# 5467    False
# 5468    False
# 5469    False
# Length: 5470, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5470 entries, 0 to 5469
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ordered              5470 non-null   int64
#  1   Number               5470 non-null   object
#  2   File name            5469 non-null   object
#  3   Organism             5470 non-null   object
#  4   muscle               5459 non-null   object
#  5   Disease Group        4940 non-null   object
#  6   Diag.Final           5228 non-null   object
#  7   GENE                 5389 non-null   object
#  8   Staining method      5468 non-null   object
#  9   Age                  5427 non-null   object
#  10  Antibody reference   62 non-null     object
#  11  Calibration (um/px)  5326 non-null   float64
#  12  Magnification        5462 non-null   object
#  13  Scale bar            5003 non-null   object
#  14  Treatment            5470 non-null   object
# ...

# %%
df1=df.dropna(subset=['Calibration (um/px)'])

# %%
NaN = df1.isna().sum()

NaN
# Out:
# ordered                   0
# Number                    0
# File name                 0
# Organism                  0
# muscle                   11
# Disease Group           454
# Diag.Final              242
# GENE                     77
# Staining method           2
# Age                      43
# Antibody reference     5264
# Calibration (um/px)       0
# Magnification             4
# Scale bar               391
# Treatment                 0
# SEXE                    213
# OMIM                    561
# Mutated gene            119
# Excluded Genes         4348
# Publication            3061
# Link                   4638
# dtype: int64

# %%
print(df1['Staining method'].value_counts())
#Nous on veut que les cellules qui sont en coloration HE et SDH
# Out:
# TEM                                                          1634
# HE                                                            737
# TG                                                            663
# NADH                                                          540
# SDH                                                           387
# ATP 9.4                                                       343
# COX                                                           164
# PAS                                                           139
# ORO                                                           122
# Desmin                                                         77
# Laminin                                                        62
# MENADIONE                                                      60
# Myotylin                                                       54
# Red Sirius                                                     48
# ...

# %%
df2=df1[(df1['Staining method'].str.contains( 'SDH|HE',na=False))] 
df2
# Out:
#       ordered    Number            File name      Organism      muscle  \
# 4           5     5.jpg    5 10199 HE-20.jpg  Homo sapiens     deltoid
# 5           6     6.jpg   6 10199 SDH-20.jpg  Homo sapiens     deltoid
# 12         13    13.jpg   13 10202 HE-20.jpg  Homo sapiens     deltoid
# 13         14    14.jpg  14 10202 SDH-20.jpg  Homo sapiens     deltoid
# 20         21    21.jpg   21 10474 HE-20.jpg  Homo sapiens  quadriceps
# ...       ...       ...                  ...           ...         ...
# 5446     5456  5456.jpg       9825 HE-40.jpg  Homo sapiens     deltoid
# 5448     5458  5458.jpg      9825 SDH-20.jpg  Homo sapiens     deltoid
# 5462     5472  5472.jpg      9948 HE-20a.jpg  Homo sapiens     deltoid
# 5463     5473  5473.jpg      9948 HE-20b.jpg  Homo sapiens     deltoid
# 5465     5475  5475.jpg      9948 SDH-20.jpg  Homo sapiens     deltoid
#
#               Disease Group                                   Diag.Final  \
# ...

# %%
df2['Staining method']
# Out:
# 4        HE
# 5       SDH
# 12       HE
# 13      SDH
# 20       HE
#        ...
# 5446     HE
# 5448    SDH
# 5462     HE
# 5463     HE
# 5465    SDH
# Name: Staining method, Length: 1136, dtype: object

# %%
print(df2['Staining method'].value_counts())
# Out:
# HE         737
# SDH        387
# COX/SDH     12
# Name: Staining method, dtype: int64

# %%
df2
# Out:
#       ordered    Number            File name      Organism      muscle  \
# 4           5     5.jpg    5 10199 HE-20.jpg  Homo sapiens     deltoid
# 5           6     6.jpg   6 10199 SDH-20.jpg  Homo sapiens     deltoid
# 12         13    13.jpg   13 10202 HE-20.jpg  Homo sapiens     deltoid
# 13         14    14.jpg  14 10202 SDH-20.jpg  Homo sapiens     deltoid
# 20         21    21.jpg   21 10474 HE-20.jpg  Homo sapiens  quadriceps
# ...       ...       ...                  ...           ...         ...
# 5446     5456  5456.jpg       9825 HE-40.jpg  Homo sapiens     deltoid
# 5448     5458  5458.jpg      9825 SDH-20.jpg  Homo sapiens     deltoid
# 5462     5472  5472.jpg      9948 HE-20a.jpg  Homo sapiens     deltoid
# 5463     5473  5473.jpg      9948 HE-20b.jpg  Homo sapiens     deltoid
# 5465     5475  5475.jpg      9948 SDH-20.jpg  Homo sapiens     deltoid
#
#               Disease Group                                   Diag.Final  \
# ...

# %%
df3=df2[ df2['Staining method' ].str.contains('COX' )==False ]

# %%
print(df3['Staining method'].value_counts())
# Out:
# HE     737
# SDH    387
# Name: Staining method, dtype: int64

# %%
df3
# Out:
#       ordered    Number            File name      Organism      muscle  \
# 4           5     5.jpg    5 10199 HE-20.jpg  Homo sapiens     deltoid
# 5           6     6.jpg   6 10199 SDH-20.jpg  Homo sapiens     deltoid
# 12         13    13.jpg   13 10202 HE-20.jpg  Homo sapiens     deltoid
# 13         14    14.jpg  14 10202 SDH-20.jpg  Homo sapiens     deltoid
# 20         21    21.jpg   21 10474 HE-20.jpg  Homo sapiens  quadriceps
# ...       ...       ...                  ...           ...         ...
# 5446     5456  5456.jpg       9825 HE-40.jpg  Homo sapiens     deltoid
# 5448     5458  5458.jpg      9825 SDH-20.jpg  Homo sapiens     deltoid
# 5462     5472  5472.jpg      9948 HE-20a.jpg  Homo sapiens     deltoid
# 5463     5473  5473.jpg      9948 HE-20b.jpg  Homo sapiens     deltoid
# 5465     5475  5475.jpg      9948 SDH-20.jpg  Homo sapiens     deltoid
#
#               Disease Group                                   Diag.Final  \
# ...

# %%
df3.set_index('Number', inplace = True)

# %%
df3
# Out:
#           ordered            File name      Organism      muscle  \
# Number
# 5.jpg           5    5 10199 HE-20.jpg  Homo sapiens     deltoid
# 6.jpg           6   6 10199 SDH-20.jpg  Homo sapiens     deltoid
# 13.jpg         13   13 10202 HE-20.jpg  Homo sapiens     deltoid
# 14.jpg         14  14 10202 SDH-20.jpg  Homo sapiens     deltoid
# 21.jpg         21   21 10474 HE-20.jpg  Homo sapiens  quadriceps
# ...           ...                  ...           ...         ...
# 5456.jpg     5456       9825 HE-40.jpg  Homo sapiens     deltoid
# 5458.jpg     5458      9825 SDH-20.jpg  Homo sapiens     deltoid
# 5472.jpg     5472      9948 HE-20a.jpg  Homo sapiens     deltoid
# 5473.jpg     5473      9948 HE-20b.jpg  Homo sapiens     deltoid
# 5475.jpg     5475      9948 SDH-20.jpg  Homo sapiens     deltoid
#
#                   Disease Group                                   Diag.Final  \
# Number
# 5.jpg      Muscular Dystrophies  Muscular Dystrophy alpha dystroglycanopathy
# ...

# %%
df3.to_csv(r'muscle_atlas_clean2.csv', index=True, header=True)
