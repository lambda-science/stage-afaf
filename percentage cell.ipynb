# %%
#Calculer pourcentages de state_cell

# %%
import pandas as pd
df=pd.read_csv('muscle_atlas_clean.csv') #atlas du muscle
df_cell=pd.read_csv('data_5_jpg.csv') # fichier info image 5 (taille, diamètre, centre...)
def conversion_pix_µm(im, data_frame,muscle_atlas):
    'Convertion du diamètre en µm'
    barre_echelle= muscle_atlas.loc[(df['Number']== im), 'Calibration (um/px)']
    
    data_frame['diameter_µm']=(data_frame['feret_diameter_max'])*barre_echelle.values

conversion_pix_µm('5.jpg',df_cell,df )

def count_atrophic_cells (data_frame,min_size, max_size):
    hyper='Hypertrophy'
    hypo= 'Hypotrophy'
    norm= 'Normal'
    data_frame["State_cell"] = ''
    for index in data_frame.index:
        a=data_frame['diameter_µm'][index]
        if a > max_size:
            data_frame["State_cell"][index]=hyper
        elif a < min_size:
            data_frame["State_cell"][index]=hypo
        else: 
            data_frame["State_cell"][index]= norm


count_atrophic_cells (df_cell, 30, 80)

df_cell
# Out:
# /var/folders/lc/l3h44z2d7_d98lsb5yh9d2y00000gn/T/ipykernel_44475/2253103963.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame["State_cell"][index]=hyper
# /var/folders/lc/l3h44z2d7_d98lsb5yh9d2y00000gn/T/ipykernel_44475/2253103963.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_frame["State_cell"][index]= norm
#     label   area  centroid-0   centroid-1  eccentricity  bbox-0  bbox-1  \
# 0       1  42573  114.372584   134.664435      0.590280       0      26
# 1       2  24120   63.611774   308.462935      0.641193       0     209
# 2       3  49842  116.046547   510.143514      0.359108       0     388
# 3       4  45595   80.636254   917.205220      0.705256       0     760
# 4       5  17997   69.825138  1241.320720      0.798332       0    1143
# 5       6  61886  186.388682  1119.213877      0.568769      11     983
# 6       7   8656  132.348082    20.894177      0.976646      13       0
# 7       8  40028  161.908689   702.735685      0.598231      29     602
# 8       9  48578  276.923628   340.470563      0.698555     135     219
# 9      10  17792  326.442952  1264.944357      0.949231     184    1209
# 10     11  43025  319.591331   906.064730      0.710462     194     789
# 11     12  47271  387.986355   226.346238      0.927667     233      89
# 12     13  23430  375.474904    40.805036      0.951484     235       0
# 13     14  52692  385.633758   527.460241      0.713008     236     411
# 14     15  53905  410.831593   745.444300      0.620854     262     622
# 15     16  60554  453.870776  1116.579466      0.506663     314     976
# 16     17  45889  543.939136   195.414152      0.802051     405      64
# 17     18  96953  684.202160  1000.089342      0.700270     487     822
# 18     19  27706  640.809428  1242.168483      0.843306     499    1162
# 19     20  37523  614.828692   731.495030      0.621346     511     610
# 20     21  38726  652.313045   530.632392      0.778509     527     439
# 21     22  55983  717.541164   360.989229      0.463724     540     215
# 22     23  46852  704.595023    90.721762      0.734250     545       0
# 23     24  21303  793.924987   649.218326      0.722032     696     567
# 24     25  17162  798.689430   770.005186      0.693853     720     701
# 25     26   7606  870.608598  1274.302787      0.929803     786    1240
# 26     27  55287  929.110966   962.369544      0.751346     811     814
# 27     28  25621  929.749541    63.038250      0.769402     818       0
# 28     29  51991  929.556943   269.469274      0.674596     819     130
# 29     30  42666  941.917921   648.577486      0.905643     841     477
# 30     31  17846  979.530315   479.090104      0.771451     901     385
#
#     bbox-2  bbox-3                                              image  \
# 0      240     253  [[False False False ... False False False]\n [...
# 1      154     422  [[False False False ... False False False]\n [...
# 2      249     631  [[False False False ... False False False]\n [...
# 3      210    1102  [[False False False ... False False False]\n [...
# 4      180    1300  [[False False False ... False False False]\n [...
# 5      334    1255  [[False False False ... False False False]\n [...
# 6      235      51  [[False False False ... False False False]\n [...
# 7      291     819  [[False False False ... False False False]\n [...
# 8      443     454  [[False False False ... False False False]\n [...
# 9      468    1300  [[False False False ... False False False]\n [...
# 10     467    1017  [[False False False ... False False False]\n [...
# 11     557     398  [[False False False ... False False False]\n [...
# 12     534      92  [[False False False ... False False False]\n [...
# 13     530     631  [[False False False ... False False False]\n [...
# 14     540     890  [[False False False ... False False False]\n [...
# 15     593    1273  [[False False False ... False False False]\n [...
# 16     663     372  [[False False False ... False False False]\n [...
# 17     844    1210  [[False False False ... False False False]\n [...
# 18     765    1300  [[False False False ... False False False]\n [...
# 19     727     839  [[False False False ... False False False]\n [...
# 20     807     623  [[False False False ... False False False]\n [...
# 21     853     487  [[False False False ... False False False]\n [...
# 22     830     213  [[False False False ... False False False]\n [...
# 23     889     731  [[False False False ... False False False]\n [...
# 24     886     840  [[False False False ... False False False]\n [...
# 25     952    1300  [[False False False ... False False False]\n [...
# 26    1030    1119  [[False False False ... False False False]\n [...
# 27    1030     136  [[False False False ... False False False]\n [...
# 28    1030     418  [[False False False ... False False False]\n [...
# 29    1030     815  [[False False False ... False False False]\n [...
# 30    1030     597  [[False False False ... False False False]\n [...
#
#       perimeter  feret_diameter_max  diameter_µm   State_cell
# 0    832.315801          274.417565    85.618280  Hypertrophy
# 1    644.238636          214.200840    66.830662       Normal
# 2    866.748304          277.650860    86.627068  Hypertrophy
# 3    951.595021          342.527371   106.868540  Hypertrophy
# 4    592.132034          223.600089    69.763228       Normal
# 5    983.986940          326.167135   101.764146  Hypertrophy
# 6    499.787843          222.324088    69.365115       Normal
# 7    802.358477          264.850901    82.633481  Hypertrophy
# 8    888.246825          309.657876    96.613257  Hypertrophy
# 9    668.132034          284.112654    88.643148  Hypertrophy
# 10   843.293506          293.552380    91.588343  Hypertrophy
# 11  1041.241774          413.175508   128.910758  Hypertrophy
# 12   722.735065          299.376018    93.405318  Hypertrophy
# 13   903.990945          307.358097    95.895726  Hypertrophy
# 14   938.536147          313.178863    97.711805  Hypertrophy
# 15   961.116882          308.768522    96.335779  Hypertrophy
# 16   907.993037          323.358934   100.887987  Hypertrophy
# 17  1256.283405          427.488012   133.376260  Hypertrophy
# 18   703.730014          268.881015    83.890877  Hypertrophy
# 19   765.369624          261.137895    81.475023  Hypertrophy
# 20   801.062013          284.606746    88.797305  Hypertrophy
# 21   988.063059          313.996815    97.967006  Hypertrophy
# 22   886.191955          322.931881   100.754747  Hypertrophy
# 23   591.813275          207.337888    64.689421       Normal
# 24   522.617316          182.060430    56.802854       Normal
# 25   395.279221          166.508258    51.950577       Normal
# 26   934.564538          325.098447   101.430715  Hypertrophy
# 27   663.693434          240.707291    75.100675       Normal
# 28   892.943218          308.609786    96.286253  Hypertrophy
# 29   907.488419          358.436884   111.832308  Hypertrophy
# 30   575.593975          212.461761    66.288070       Normal

# %%
#test 
percentage= (df_cell['State_cell'].value_counts()/df_cell['State_cell'].count())*100
serie_to_df= pd.Series.to_frame(percentage).transpose()
serie_to_df['Hypotrophy']=0
serie_to_df
# Out:
#             Hypertrophy     Normal  Hypotrophy
# State_cell    74.193548  25.806452           0

# %%
data = {'Number': ['im'], 'Hypertrophy': [],'Normal':[],'Hypotrophy': []}  
df_state_cell = pd.DataFrame(data)  
df_state_cell
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [35], line 2
#       1 data = {'Number': ['im'], 'Hypertrophy': [],'Normal':[],'Hypotrophy': []}
# ----> 2 df_state_cell = pd.DataFrame(data)
#       3 df_state_cell
#
# File ~/opt/anaconda3/envs/stage-afaf/lib/python3.9/site-packages/pandas/core/frame.py:662, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     656     mgr = self._init_mgr(
#     657         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     658     )
#     660 elif isinstance(data, dict):
#     661     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 662     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     663 elif isinstance(data, ma.MaskedArray):
#     664     import numpy.ma.mrecords as mrecords
#
# File ~/opt/anaconda3/envs/stage-afaf/lib/python3.9/site-packages/pandas/core/internals/construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/opt/anaconda3/envs/stage-afaf/lib/python3.9/site-packages/pandas/core/internals/construction.py:118, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     115 if verify_integrity:
#     116     # figure out the index, if necessary
#     117     if index is None:
# --> 118         index = _extract_index(arrays)
#     119     else:
#     120         index = ensure_index(index)
#
# File ~/opt/anaconda3/envs/stage-afaf/lib/python3.9/site-packages/pandas/core/internals/construction.py:666, in _extract_index(data)
#     664 lengths = list(set(raw_lengths))
#     665 if len(lengths) > 1:
# --> 666     raise ValueError("All arrays must be of the same length")
#     668 if have_dicts:
#     669     raise ValueError(
#     670         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     671     )
#
# ValueError: All arrays must be of the same length

# %%
percentage= (df_cell['State_cell'].value_counts()/df_cell['State_cell'].count())*100
print(percentage)
# Out:
# Hypertrophy    74.193548
# Normal         25.806452
# Name: State_cell, dtype: float64

# %%
df_state_cell.loc[len(df_state_cell.index)] = percentage
df_state_cell
# Out:
#    Number  Hypertrophy     Normal  Hypotrophy
# 0     NaN    74.193548  25.806452         NaN

# %%
def pourcentage (im,data_frame):
     data = {'Number':[im],'Hypertrophy': [],'Normal':[],'Hypotrophy': []}  # Ici on créer un dataframe pour mettre ensuite les valeurs des pourcentages
     df_state_cell = pd.DataFrame(data)  
     percentage= (data_frame['State_cell'].value_counts()/data_frame['State_cell'].count())*100
     df_state_cell.loc[len(df_state_cell.index)] = percentage

pourcentage ('5.jpg',df_cell)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [34], line 7
#       4      percentage= (data_frame['State_cell'].value_counts()/data_frame['State_cell'].count())*100
#       5      df_state_cell.loc[len(df_state_cell.index)] = percentage
# ----> 7 pourcentage ('5.jpg',df_cell)
#
# Cell In [34], line 3, in pourcentage(im, data_frame)
#       1 def pourcentage (im,data_frame):
#       2      data = {'Number':[im],'Hypertrophy': [],'Normal':[],'Hypotrophy': []}  # Ici on créer un dataframe pour mettre ensuite les valeurs des pourcentages
# ----> 3      df_state_cell = pd.DataFrame(data)
#       4      percentage= (data_frame['State_cell'].value_counts()/data_frame['State_cell'].count())*100
#       5      df_state_cell.loc[len(df_state_cell.index)] = percentage
#
# File ~/opt/anaconda3/envs/stage-afaf/lib/python3.9/site-packages/pandas/core/frame.py:662, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     656     mgr = self._init_mgr(
#     657         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     658     )
#     660 elif isinstance(data, dict):
#     661     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 662     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     663 elif isinstance(data, ma.MaskedArray):
#     664     import numpy.ma.mrecords as mrecords
#
# File ~/opt/anaconda3/envs/stage-afaf/lib/python3.9/site-packages/pandas/core/internals/construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/opt/anaconda3/envs/stage-afaf/lib/python3.9/site-packages/pandas/core/internals/construction.py:118, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     115 if verify_integrity:
#     116     # figure out the index, if necessary
#     117     if index is None:
# --> 118         index = _extract_index(arrays)
#     119     else:
#     120         index = ensure_index(index)
#
# File ~/opt/anaconda3/envs/stage-afaf/lib/python3.9/site-packages/pandas/core/internals/construction.py:666, in _extract_index(data)
#     664 lengths = list(set(raw_lengths))
#     665 if len(lengths) > 1:
# --> 666     raise ValueError("All arrays must be of the same length")
#     668 if have_dicts:
#     669     raise ValueError(
#     670         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     671     )
#
# ValueError: All arrays must be of the same length

# %%
def pourcentage_state_cell (im,data_frame,muscle_atlas):
     data = {'Number':[im],'Hypertrophy': [],'Normal':[],'Hypotrophy': []}  # Ici on créer un dataframe pour mettre ensuite les valeurs des pourcentages
     df_state_cell = pd.DataFrame(data)  
     percentage= (data_frame['State_cell'].value_counts()/data_frame['State_cell'].count())*100
     df_state_cell.loc[len(df_state_cell.index)] = percentage

     
     #muscle_atlas.loc[(muscle_atlas['Number']== im),"Hypertrophic_cell_%"]=df_state_cell['Hypertrophy'].values
     #muscle_atlas.loc[(muscle_atlas['Number']== im),"Normal_cell_%"]=df_state_cell['Normal'].values
     #muscle_atlas.loc[(muscle_atlas['Number']== im),"Hypotrophic_cell_%"]=df_state_cell['Hypotrophy'].values


pourcentage_state_cell ('5.jpg',df_cell,df)   

df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [32], line 13
#       5      df_state_cell.loc[len(df_state_cell.index)] = percentage
#       8      #muscle_atlas.loc[(muscle_atlas['Number']== im),"Hypertrophic_cell_%"]=df_state_cell['Hypertrophy'].values
#       9      #muscle_atlas.loc[(muscle_atlas['Number']== im),"Normal_cell_%"]=df_state_cell['Normal'].values
#      10      #muscle_atlas.loc[(muscle_atlas['Number']== im),"Hypotrophic_cell_%"]=df_state_cell['Hypotrophy'].values
# ---> 13 pourcentage_state_cell ('5.jpg',df_cell,df)
#      15 df
#
# Cell In [32], line 3, in pourcentage_state_cell(im, data_frame, muscle_atlas)
#       1 def pourcentage_state_cell (im,data_frame,muscle_atlas):
#       2      data = {'Number':[im],'Hypertrophy': [],'Normal':[],'Hypotrophy': []}  # Ici on créer un dataframe pour mettre ensuite les valeurs des pourcentages
# ----> 3      df_state_cell = pd.DataFrame(data)
#       4      percentage= (data_frame['State_cell'].value_counts()/data_frame['State_cell'].count())*100
#       5      df_state_cell.loc[len(df_state_cell.index)] = percentage
#
# File ~/opt/anaconda3/envs/stage-afaf/lib/python3.9/site-packages/pandas/core/frame.py:662, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     656     mgr = self._init_mgr(
#     657         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     658     )
#     660 elif isinstance(data, dict):
#     661     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 662     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     663 elif isinstance(data, ma.MaskedArray):
#     664     import numpy.ma.mrecords as mrecords
#
# File ~/opt/anaconda3/envs/stage-afaf/lib/python3.9/site-packages/pandas/core/internals/construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/opt/anaconda3/envs/stage-afaf/lib/python3.9/site-packages/pandas/core/internals/construction.py:118, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     115 if verify_integrity:
#     116     # figure out the index, if necessary
#     117     if index is None:
# --> 118         index = _extract_index(arrays)
#     119     else:
#     120         index = ensure_index(index)
#
# File ~/opt/anaconda3/envs/stage-afaf/lib/python3.9/site-packages/pandas/core/internals/construction.py:666, in _extract_index(data)
#     664 lengths = list(set(raw_lengths))
#     665 if len(lengths) > 1:
# --> 666     raise ValueError("All arrays must be of the same length")
#     668 if have_dicts:
#     669     raise ValueError(
#     670         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     671     )
#
# ValueError: All arrays must be of the same length
